# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
  """
  Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
  it for the linear classifier. These are the same steps as we used for the
  SVM, but condensed to a single function.  
  """
  # Load the raw CIFAR-10 data
  cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # subsample the data
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]
  mask = np.random.choice(num_training, num_dev, replace=False)
  X_dev = X_train[mask]
  y_dev = y_train[mask]
  
  # Preprocessing: reshape the image data into rows
  X_train = np.reshape(X_train, (X_train.shape[0], -1))
  X_val = np.reshape(X_val, (X_val.shape[0], -1))
  X_test = np.reshape(X_test, (X_test.shape[0], -1))
  X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
  
  # Normalize the data: subtract the mean image
  mean_image = np.mean(X_train, axis = 0)
  X_train -= mean_image
  X_val -= mean_image
  X_test -= mean_image
  X_dev -= mean_image
  
  # add bias dimension and transform into columns
  X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
  X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
  X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
  X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
  
  return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
print 'dev data shape: ', X_dev.shape
print 'dev labels shape: ', y_dev.shape
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print 'loss: %f' % loss
print 'sanity check: %f' % (-np.log(0.1))
# Out:
# loss: 2.349435
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 1e2)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 1e2)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 0.192586 analytic: 0.192586, relative error: 2.848778e-07
# numerical: -2.889855 analytic: -2.889855, relative error: 2.727409e-08
# numerical: -1.928029 analytic: -1.928029, relative error: 2.679217e-08
# numerical: -3.892677 analytic: -3.892677, relative error: 1.976360e-08
# numerical: -0.989696 analytic: -0.989697, relative error: 7.861305e-08
# numerical: 0.715425 analytic: 0.715425, relative error: 6.267896e-08
# numerical: -0.211118 analytic: -0.211118, relative error: 1.039662e-07
# numerical: -1.154117 analytic: -1.154117, relative error: 2.597889e-08
# numerical: -0.068595 analytic: -0.068595, relative error: 5.175129e-07
# numerical: 1.163590 analytic: 1.163589, relative error: 7.378549e-08
# numerical: -0.176073 analytic: -0.176074, relative error: 2.578723e-07
# numerical: 0.693015 analytic: 0.693015, relative error: 5.224596e-08
# numerical: 1.916312 analytic: 1.916312, relative error: 2.516041e-08
# numerical: 0.345687 analytic: 0.345687, relative error: 1.668049e-07
# numerical: -0.071767 analytic: -0.071767, relative error: 6.094339e-07
# numerical: -0.141923 analytic: -0.141923, relative error: 3.644239e-07
# numerical: -0.093210 analytic: -0.093210, relative error: 3.478435e-07
# numerical: 0.180145 analytic: 0.180144, relative error: 4.394692e-07
# numerical: -4.278786 analytic: -4.278786, relative error: 7.041878e-09
# numerical: -5.535036 analytic: -5.535037, relative error: 1.168679e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'naive loss: %e computed in %fs' % (loss_naive, toc - tic)

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic)

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print 'Loss difference: %f' % np.abs(loss_naive - loss_vectorized)
print 'Gradient difference: %f' % grad_difference
# Out:
# naive loss: 2.349435e+00 computed in 0.166488s
# vectorized loss: 2.349435e+00 computed in 0.005117s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [6e-8, 8e-8, 1e-7, 1.2e-7, 1.4e-7]
regularization_strengths = [4e4, 5e4, 6e4]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
for i in learning_rates:
    for j in regularization_strengths:
        cls = Softmax()
        cls.train(X_train, y_train, learning_rate=i, reg=j, num_iters=2500, verbose=True)
        acc1 = np.mean(cls.predict(X_train) == y_train)
        acc2 =  np.mean(cls.predict(X_val) == y_val)
        results[(i,j)] = (acc1, acc2)
        print acc1, acc2
        if acc2 > best_val:
            best_val, best_softmax = acc2, cls
        
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
# Out:
# iteration 0 / 2500: loss 614.429692
# iteration 100 / 2500: loss 379.197190
# iteration 200 / 2500: loss 234.792315
# iteration 300 / 2500: loss 145.807830
# iteration 400 / 2500: loss 90.790203
# iteration 500 / 2500: loss 56.774629
# iteration 600 / 2500: loss 35.917226
# iteration 700 / 2500: loss 23.016116
# iteration 800 / 2500: loss 15.025661
# iteration 900 / 2500: loss 10.005496
# iteration 1000 / 2500: loss 7.084771
# iteration 1100 / 2500: loss 5.184803
# iteration 1200 / 2500: loss 3.931955
# iteration 1300 / 2500: loss 3.202258
# iteration 1400 / 2500: loss 2.797503
# iteration 1500 / 2500: loss 2.552680
# iteration 1600 / 2500: loss 2.364259
# iteration 1700 / 2500: loss 2.292015
# iteration 1800 / 2500: loss 2.188540
# iteration 1900 / 2500: loss 2.101017
# iteration 2000 / 2500: loss 2.178863
# iteration 2100 / 2500: loss 2.064732
# iteration 2200 / 2500: loss 2.074194
# iteration 2300 / 2500: loss 2.077029
# iteration 2400 / 2500: loss 2.072622
# 0.332632653061 0.35
# iteration 0 / 2500: loss 778.629395
# iteration 100 / 2500: loss 426.706501
# iteration 200 / 2500: loss 234.612456
# iteration 300 / 2500: loss 129.398399
# iteration 400 / 2500: loss 71.749848
# iteration 500 / 2500: loss 40.220907
# iteration 600 / 2500: loss 22.996129
# iteration 700 / 2500: loss 13.484202
# iteration 800 / 2500: loss 8.382786
# iteration 900 / 2500: loss 5.505140
# iteration 1000 / 2500: loss 3.984478
# iteration 1100 / 2500: loss 3.141632
# iteration 1200 / 2500: loss 2.662376
# iteration 1300 / 2500: loss 2.362788
# iteration 1400 / 2500: loss 2.242243
# iteration 1500 / 2500: loss 2.185860
# iteration 1600 / 2500: loss 2.107542
# iteration 1700 / 2500: loss 2.060292
# iteration 1800 / 2500: loss 2.085104
# iteration 1900 / 2500: loss 2.150487
# iteration 2000 / 2500: loss 2.080437
# iteration 2100 / 2500: loss 2.010436
# iteration 2200 / 2500: loss 2.087293
# iteration 2300 / 2500: loss 2.149869
# iteration 2400 / 2500: loss 2.138659
# 0.327673469388 0.341
# iteration 0 / 2500: loss 924.361850
# iteration 100 / 2500: loss 448.785882
# iteration 200 / 2500: loss 218.908083
# iteration 300 / 2500: loss 107.366078
# iteration 400 / 2500: loss 53.151045
# iteration 500 / 2500: loss 26.826044
# iteration 600 / 2500: loss 14.149331
# iteration 700 / 2500: loss 7.961449
# iteration 800 / 2500: loss 4.860486
# iteration 900 / 2500: loss 3.489004
# iteration 1000 / 2500: loss 2.781632
# iteration 1100 / 2500: loss 2.402524
# iteration 1200 / 2500: loss 2.282494
# iteration 1300 / 2500: loss 2.157512
# iteration 1400 / 2500: loss 2.117798
# iteration 1500 / 2500: loss 2.122480
# iteration 1600 / 2500: loss 2.103441
# iteration 1700 / 2500: loss 2.139892
# iteration 1800 / 2500: loss 2.131790
# iteration 1900 / 2500: loss 2.120186
# iteration 2000 / 2500: loss 2.126955
# iteration 2100 / 2500: loss 2.070338
# iteration 2200 / 2500: loss 2.128406
# iteration 2300 / 2500: loss 2.052981
# iteration 2400 / 2500: loss 2.056557
# 0.323163265306 0.342
# iteration 0 / 2500: loss 618.577324
# iteration 100 / 2500: loss 325.460819
# iteration 200 / 2500: loss 171.931336
# iteration 300 / 2500: loss 91.298186
# iteration 400 / 2500: loss 49.049642
# iteration 500 / 2500: loss 26.695126
# iteration 600 / 2500: loss 15.086421
# iteration 700 / 2500: loss 8.853264
# iteration 800 / 2500: loss 5.659090
# iteration 900 / 2500: loss 3.966785
# iteration 1000 / 2500: loss 3.056650
# iteration 1100 / 2500: loss 2.584920
# iteration 1200 / 2500: loss 2.319386
# iteration 1300 / 2500: loss 2.130929
# iteration 1400 / 2500: loss 2.177034
# iteration 1500 / 2500: loss 2.112644
# iteration 1600 / 2500: loss 2.038136
# iteration 1700 / 2500: loss 2.072237
# iteration 1800 / 2500: loss 2.086996
# iteration 1900 / 2500: loss 2.065494
# iteration 2000 / 2500: loss 2.086016
# iteration 2100 / 2500: loss 2.034125
# iteration 2200 / 2500: loss 2.092364
# iteration 2300 / 2500: loss 2.114037
# iteration 2400 / 2500: loss 1.989541
# 0.335306122449 0.351
# iteration 0 / 2500: loss 769.734509
# iteration 100 / 2500: loss 345.074368
# iteration 200 / 2500: loss 155.546839
# iteration 300 / 2500: loss 70.690153
# iteration 400 / 2500: loss 32.907420
# iteration 500 / 2500: loss 15.851820
# iteration 600 / 2500: loss 8.224669
# iteration 700 / 2500: loss 4.810932
# iteration 800 / 2500: loss 3.272441
# iteration 900 / 2500: loss 2.589904
# iteration 1000 / 2500: loss 2.394565
# iteration 1100 / 2500: loss 2.196571
# iteration 1200 / 2500: loss 2.175649
# iteration 1300 / 2500: loss 2.060822
# iteration 1400 / 2500: loss 2.077738
# iteration 1500 / 2500: loss 2.098346
# iteration 1600 / 2500: loss 2.056319
# iteration 1700 / 2500: loss 2.092380
# iteration 1800 / 2500: loss 2.095139
# iteration 1900 / 2500: loss 2.113860
# iteration 2000 / 2500: loss 2.143335
# iteration 2100 / 2500: loss 2.098597
# iteration 2200 / 2500: loss 2.042215
# iteration 2300 / 2500: loss 2.121537
# iteration 2400 / 2500: loss 2.073040
# 0.328244897959 0.343
# iteration 0 / 2500: loss 933.202136
# iteration 100 / 2500: loss 356.299297
# iteration 200 / 2500: loss 137.139777
# iteration 300 / 2500: loss 53.497958
# iteration 400 / 2500: loss 21.685179
# iteration 500 / 2500: loss 9.603129
# iteration 600 / 2500: loss 4.922429
# iteration 700 / 2500: loss 3.216977
# iteration 800 / 2500: loss 2.544550
# iteration 900 / 2500: loss 2.219165
# iteration 1000 / 2500: loss 2.143192
# iteration 1100 / 2500: loss 2.117863
# iteration 1200 / 2500: loss 2.086397
# iteration 1300 / 2500: loss 2.087911
# iteration 1400 / 2500: loss 2.097527
# iteration 1500 / 2500: loss 2.093799
# iteration 1600 / 2500: loss 2.108907
# iteration 1700 / 2500: loss 2.112411
# iteration 1800 / 2500: loss 2.096732
# iteration 1900 / 2500: loss 2.090536
# iteration 2000 / 2500: loss 2.087333
# iteration 2100 / 2500: loss 2.106574
# iteration 2200 / 2500: loss 2.080617
# iteration 2300 / 2500: loss 2.177982
# iteration 2400 / 2500: loss 2.147529
# 0.331183673469 0.345
# iteration 0 / 2500: loss 620.304475
# iteration 100 / 2500: loss 278.490053
# iteration 200 / 2500: loss 125.505706
# iteration 300 / 2500: loss 57.421321
# iteration 400 / 2500: loss 26.788477
# iteration 500 / 2500: loss 13.149964
# iteration 600 / 2500: loss 7.090753
# iteration 700 / 2500: loss 4.294871
# iteration 800 / 2500: loss 3.050291
# iteration 900 / 2500: loss 2.487925
# iteration 1000 / 2500: loss 2.264923
# iteration 1100 / 2500: loss 2.166988
# iteration 1200 / 2500: loss 2.039513
# iteration 1300 / 2500: loss 2.078146
# iteration 1400 / 2500: loss 2.081439
# iteration 1500 / 2500: loss 2.080800
# iteration 1600 / 2500: loss 1.998474
# iteration 1700 / 2500: loss 2.049019
# iteration 1800 / 2500: loss 2.173571
# iteration 1900 / 2500: loss 2.075699
# iteration 2000 / 2500: loss 2.003783
# iteration 2100 / 2500: loss 2.002924
# iteration 2200 / 2500: loss 2.041673
# iteration 2300 / 2500: loss 2.053063
# iteration 2400 / 2500: loss 2.057116
# 0.338306122449 0.35
# iteration 0 / 2500: loss 783.959987
# iteration 100 / 2500: loss 287.425738
# iteration 200 / 2500: loss 106.581485
# iteration 300 / 2500: loss 40.357883
# iteration 400 / 2500: loss 16.090330
# iteration 500 / 2500: loss 7.225681
# iteration 600 / 2500: loss 4.009838
# iteration 700 / 2500: loss 2.870391
# iteration 800 / 2500: loss 2.334138
# iteration 900 / 2500: loss 2.174054
# iteration 1000 / 2500: loss 2.059988
# iteration 1100 / 2500: loss 2.122156
# iteration 1200 / 2500: loss 2.086125
# iteration 1300 / 2500: loss 2.117713
# iteration 1400 / 2500: loss 2.073076
# iteration 1500 / 2500: loss 2.066378
# iteration 1600 / 2500: loss 2.062724
# iteration 1700 / 2500: loss 2.063675
# iteration 1800 / 2500: loss 2.143138
# iteration 1900 / 2500: loss 2.073577
# iteration 2000 / 2500: loss 2.088775
# iteration 2100 / 2500: loss 2.048002
# iteration 2200 / 2500: loss 2.047026
# iteration 2300 / 2500: loss 2.054599
# iteration 2400 / 2500: loss 2.064756
# 0.327469387755 0.347
# iteration 0 / 2500: loss 931.357117
# iteration 100 / 2500: loss 279.949514
# iteration 200 / 2500: loss 85.122019
# iteration 300 / 2500: loss 26.950484
# iteration 400 / 2500: loss 9.533918
# iteration 500 / 2500: loss 4.285981
# iteration 600 / 2500: loss 2.834967
# iteration 700 / 2500: loss 2.299909
# iteration 800 / 2500: loss 2.215122
# iteration 900 / 2500: loss 2.109482
# iteration 1000 / 2500: loss 2.090627
# iteration 1100 / 2500: loss 2.132881
# iteration 1200 / 2500: loss 2.090605
# iteration 1300 / 2500: loss 2.097829
# iteration 1400 / 2500: loss 2.056563
# iteration 1500 / 2500: loss 2.107718
# iteration 1600 / 2500: loss 2.100835
# iteration 1700 / 2500: loss 2.095264
# iteration 1800 / 2500: loss 2.105843
# iteration 1900 / 2500: loss 2.124816
# iteration 2000 / 2500: loss 2.116977
# iteration 2100 / 2500: loss 2.130789
# iteration 2200 / 2500: loss 2.079124
# iteration 2300 / 2500: loss 2.094474
# iteration 2400 / 2500: loss 2.049366
# 0.324428571429 0.34
# iteration 0 / 2500: loss 627.388504
# iteration 100 / 2500: loss 239.200800
# iteration 200 / 2500: loss 92.352550
# iteration 300 / 2500: loss 36.422250
# iteration 400 / 2500: loss 15.150376
# iteration 500 / 2500: loss 7.026560
# iteration 600 / 2500: loss 3.887483
# iteration 700 / 2500: loss 2.811497
# iteration 800 / 2500: loss 2.348701
# iteration 900 / 2500: loss 2.193503
# iteration 1000 / 2500: loss 2.031816
# iteration 1100 / 2500: loss 2.107966
# iteration 1200 / 2500: loss 2.098556
# iteration 1300 / 2500: loss 2.152821
# iteration 1400 / 2500: loss 2.046344
# iteration 1500 / 2500: loss 2.083610
# iteration 1600 / 2500: loss 2.076212
# iteration 1700 / 2500: loss 2.041043
# iteration 1800 / 2500: loss 2.028335
# iteration 1900 / 2500: loss 2.120175
# iteration 2000 / 2500: loss 2.102626
# iteration 2100 / 2500: loss 2.045731
# iteration 2200 / 2500: loss 2.094036
# iteration 2300 / 2500: loss 2.056069
# iteration 2400 / 2500: loss 2.039423
# 0.337591836735 0.353
# iteration 0 / 2500: loss 766.728739
# iteration 100 / 2500: loss 230.414887
# iteration 200 / 2500: loss 70.371845
# iteration 300 / 2500: loss 22.455851
# iteration 400 / 2500: loss 8.205809
# iteration 500 / 2500: loss 3.906161
# iteration 600 / 2500: loss 2.654406
# iteration 700 / 2500: loss 2.288804
# iteration 800 / 2500: loss 2.075455
# iteration 900 / 2500: loss 2.063554
# iteration 1000 / 2500: loss 2.089751
# iteration 1100 / 2500: loss 2.042895
# iteration 1200 / 2500: loss 2.121550
# iteration 1300 / 2500: loss 2.100791
# iteration 1400 / 2500: loss 2.128013
# iteration 1500 / 2500: loss 2.071868
# iteration 1600 / 2500: loss 2.049608
# iteration 1700 / 2500: loss 2.107005
# iteration 1800 / 2500: loss 2.124143
# iteration 1900 / 2500: loss 2.074502
# iteration 2000 / 2500: loss 2.057586
# iteration 2100 / 2500: loss 2.110163
# iteration 2200 / 2500: loss 2.032650
# iteration 2300 / 2500: loss 2.031539
# iteration 2400 / 2500: loss 2.064346
# 0.338755102041 0.353
# iteration 0 / 2500: loss 938.139925
# iteration 100 / 2500: loss 221.572724
# iteration 200 / 2500: loss 53.624424
# iteration 300 / 2500: loss 14.201268
# iteration 400 / 2500: loss 4.967956
# iteration 500 / 2500: loss 2.761177
# iteration 600 / 2500: loss 2.245236
# iteration 700 / 2500: loss 2.083366
# iteration 800 / 2500: loss 2.059857
# iteration 900 / 2500: loss 2.136850
# iteration 1000 / 2500: loss 2.070964
# iteration 1100 / 2500: loss 2.070177
# iteration 1200 / 2500: loss 2.111751
# iteration 1300 / 2500: loss 2.061514
# iteration 1400 / 2500: loss 2.086000
# iteration 1500 / 2500: loss 2.054091
# iteration 1600 / 2500: loss 2.062520
# iteration 1700 / 2500: loss 2.148680
# iteration 1800 / 2500: loss 2.127357
# iteration 1900 / 2500: loss 2.084650
# iteration 2000 / 2500: loss 2.114937
# iteration 2100 / 2500: loss 2.090594
# iteration 2200 / 2500: loss 2.102930
# iteration 2300 / 2500: loss 2.100654
# iteration 2400 / 2500: loss 2.086048
# 0.317571428571 0.34
# iteration 0 / 2500: loss 624.778063
# iteration 100 / 2500: loss 203.198812
# iteration 200 / 2500: loss 67.184131
# iteration 300 / 2500: loss 23.175073
# iteration 400 / 2500: loss 8.917700
# iteration 500 / 2500: loss 4.350803
# iteration 600 / 2500: loss 2.868315
# iteration 700 / 2500: loss 2.303400
# iteration 800 / 2500: loss 2.136745
# iteration 900 / 2500: loss 2.107215
# iteration 1000 / 2500: loss 2.065804
# iteration 1100 / 2500: loss 2.076749
# iteration 1200 / 2500: loss 2.037232
# iteration 1300 / 2500: loss 2.078165
# iteration 1400 / 2500: loss 2.090976
# iteration 1500 / 2500: loss 2.004741
# iteration 1600 / 2500: loss 2.077906
# iteration 1700 / 2500: loss 2.072499
# iteration 1800 / 2500: loss 2.117692
# iteration 1900 / 2500: loss 2.030138
# iteration 2000 / 2500: loss 2.151242
# iteration 2100 / 2500: loss 2.079208
# iteration 2200 / 2500: loss 2.112955
# iteration 2300 / 2500: loss 2.069199
# iteration 2400 / 2500: loss 2.078866
# 0.337367346939 0.355
# iteration 0 / 2500: loss 784.432440
# iteration 100 / 2500: loss 192.836137
# iteration 200 / 2500: loss 48.727723
# iteration 300 / 2500: loss 13.504909
# iteration 400 / 2500: loss 4.864664
# iteration 500 / 2500: loss 2.720671
# iteration 600 / 2500: loss 2.280438
# iteration 700 / 2500: loss 2.147974
# iteration 800 / 2500: loss 2.086327
# iteration 900 / 2500: loss 2.078161
# iteration 1000 / 2500: loss 2.043692
# iteration 1100 / 2500: loss 2.086278
# iteration 1200 / 2500: loss 2.053514
# iteration 1300 / 2500: loss 2.013034
# iteration 1400 / 2500: loss 2.169746
# iteration 1500 / 2500: loss 2.046178
# iteration 1600 / 2500: loss 2.064954
# iteration 1700 / 2500: loss 2.063732
# iteration 1800 / 2500: loss 2.088954
# iteration 1900 / 2500: loss 2.060386
# iteration 2000 / 2500: loss 2.089312
# iteration 2100 / 2500: loss 2.098831
# iteration 2200 / 2500: loss 2.106877
# iteration 2300 / 2500: loss 2.095529
# iteration 2400 / 2500: loss 2.131154
# 0.331224489796 0.34
# iteration 0 / 2500: loss 929.110601
# iteration 100 / 2500: loss 172.659428
# iteration 200 / 2500: loss 33.547683
# iteration 300 / 2500: loss 7.962915
# iteration 400 / 2500: loss 3.143636
# iteration 500 / 2500: loss 2.218455
# iteration 600 / 2500: loss 2.186513
# iteration 700 / 2500: loss 2.124011
# iteration 800 / 2500: loss 2.063114
# iteration 900 / 2500: loss 2.174749
# iteration 1000 / 2500: loss 2.074924
# iteration 1100 / 2500: loss 2.109756
# iteration 1200 / 2500: loss 2.105444
# iteration 1300 / 2500: loss 2.094170
# iteration 1400 / 2500: loss 2.108066
# iteration 1500 / 2500: loss 2.066076
# iteration 1600 / 2500: loss 2.140885
# iteration 1700 / 2500: loss 2.087297
# iteration 1800 / 2500: loss 2.086793
# iteration 1900 / 2500: loss 2.122563
# iteration 2000 / 2500: loss 2.103950
# iteration 2100 / 2500: loss 2.108062
# iteration 2200 / 2500: loss 2.118080
# iteration 2300 / 2500: loss 2.058759
# iteration 2400 / 2500: loss 2.158112
# 0.330244897959 0.339
# lr 6.000000e-08 reg 4.000000e+04 train accuracy: 0.332633 val accuracy: 0.350000
# lr 6.000000e-08 reg 5.000000e+04 train accuracy: 0.327673 val accuracy: 0.341000
# lr 6.000000e-08 reg 6.000000e+04 train accuracy: 0.323163 val accuracy: 0.342000
# lr 8.000000e-08 reg 4.000000e+04 train accuracy: 0.335306 val accuracy: 0.351000
# lr 8.000000e-08 reg 5.000000e+04 train accuracy: 0.328245 val accuracy: 0.343000
# lr 8.000000e-08 reg 6.000000e+04 train accuracy: 0.331184 val accuracy: 0.345000
# lr 1.000000e-07 reg 4.000000e+04 train accuracy: 0.338306 val accuracy: 0.350000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.327469 val accuracy: 0.347000
# lr 1.000000e-07 reg 6.000000e+04 train accuracy: 0.324429 val accuracy: 0.340000
# lr 1.200000e-07 reg 4.000000e+04 train accuracy: 0.337592 val accuracy: 0.353000
# lr 1.200000e-07 reg 5.000000e+04 train accuracy: 0.338755 val accuracy: 0.353000
# lr 1.200000e-07 reg 6.000000e+04 train accuracy: 0.317571 val accuracy: 0.340000
# lr 1.400000e-07 reg 4.000000e+04 train accuracy: 0.337367 val accuracy: 0.355000
# lr 1.400000e-07 reg 5.000000e+04 train accuracy: 0.331224 val accuracy: 0.340000
# lr 1.400000e-07 reg 6.000000e+04 train accuracy: 0.330245 val accuracy: 0.339000
# best validation accuracy achieved during cross-validation: 0.355000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print 'softmax on raw pixels final test set accuracy: %f' % (test_accuracy, )
# Out:
# softmax on raw pixels final test set accuracy: 0.340000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in xrange(10):
  plt.subplot(2, 5, i + 1)
  
  # Rescale the weights to be between 0 and 255
  wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
  plt.imshow(wimg.astype('uint8'))
  plt.axis('off')
  plt.title(classes[i])
